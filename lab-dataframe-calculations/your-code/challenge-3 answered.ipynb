# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set. In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# Import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, extract and import `Orders` dataset into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# Get the data
data = pd.read_csv('Orders.csv')
data
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3       knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4            red woolly hottie white heart.         6  2010-12-01 08:26:00
# ...                                     ...       ...                  ...
# 397919          pack of 20 spaceboy napkins        12  2011-12-09 12:50:00
# 397920         children's apron dolly girl          6  2011-12-09 12:50:00
# 397921        childrens cutlery dolly girl          4  2011-12-09 12:50:00
# 397922      childrens cutlery circus parade         4  2011-12-09 12:50:00
# 397923        baking set 9 piece retrospot          3  2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 0            2.55       17850  United Kingdom         15.30
# 1            3.39       17850  United Kingdom         20.34
# 2            2.75       17850  United Kingdom         22.00
# 3            3.39       17850  United Kingdom         20.34
# 4            3.39       17850  United Kingdom         20.34
# ...           ...         ...             ...           ...
# 397919       0.85       12680          France         10.20
# 397920       2.10       12680          France         12.60
# 397921       4.15       12680          France         16.60
# 397922       4.15       12680          France         16.60
# 397923       4.95       12680          France         14.85
#
# [397924 rows x 14 columns]

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?

# %%
# Get the total amount spent per client
data2 = data['amount_spent'].groupby(by= data['CustomerID'], axis=0, dropna=True).sum()
data2 = pd.DataFrame(data2)
data2 = data2.reset_index()
data2
# Out:
#       CustomerID  amount_spent
# 0          12346      77183.60
# 1          12347       4310.00
# 2          12348       1797.24
# 3          12349       1757.55
# 4          12350        334.40
# ...          ...           ...
# 4334       18280        180.60
# 4335       18281         80.82
# 4336       18282        178.05
# 4337       18283       2094.88
# 4338       18287       1837.28
#
# [4339 rows x 2 columns]

# %%
# Get a dataset for later
country = pd.DataFrame(data['Country'],data['CustomerID'])
country = country.reset_index()
country = country.drop_duplicates('CustomerID')
country
# Out:
#         CustomerID         Country
# 0            17850  United Kingdom
# 9            13047  United Kingdom
# 26           12583  United Kingdom
# 46           13748  United Kingdom
# 65           15100  United Kingdom
# ...            ...             ...
# 394965       13436  United Kingdom
# 395041       15520  United Kingdom
# 395777       13298  United Kingdom
# 396506       14569  United Kingdom
# 397783       12713          Norway
#
# [4339 rows x 2 columns]

# %% [markdown]
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?

# %%
# Get amount threshold per given quantiles
percentiles = data2.describe(percentiles=[ .75, .95])
percentiles = percentiles.drop(['CustomerID'],axis=1)
percentiles.columns = ['Threshold Amount for given quantiles']
percentiles = percentiles.T
percentiles = percentiles.drop(['count', 'mean' , 'std', 'min', '50%', 'max'],axis=1)
percentiles
# Out:
#                                           75%       95%
# Threshold Amount for given quantiles  1661.64  5840.182

# %% [markdown]
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# Building function to return labels
def quantile_class(row):
    if row['amount_spent'] >= np.percentile(data2['amount_spent'], 95) :
        return 'VIP'
    elif row['amount_spent'] <= np.percentile(data2['amount_spent'], 75):
        return np.nan
    else:
        return 'Preferred'

# %%
# Apply the function to populate the column Client Class
# dataframe[column] = dataframe.apply(function, dataframe, axis)
data2['Client Class'] = data2.apply(quantile_class, axis =1)
data2 = data2.dropna()
data2
# Out:
#       CustomerID  amount_spent Client Class
# 0          12346      77183.60          VIP
# 1          12347       4310.00    Preferred
# 2          12348       1797.24    Preferred
# 3          12349       1757.55    Preferred
# 5          12352       2506.04    Preferred
# ...          ...           ...          ...
# 4319       18259       2338.60    Preferred
# 4320       18260       2643.20    Preferred
# 4328       18272       3078.58    Preferred
# 4337       18283       2094.88    Preferred
# 4338       18287       1837.28    Preferred
#
# [1085 rows x 3 columns]

# %%
# Merge the country dataset to my dataframe
data3 = data2.merge(country, left_on='CustomerID',right_on='CustomerID')
data3.sample(25)
# Out:
#       CustomerID  amount_spent Client Class         Country
# 1049       18093       2106.52    Preferred  United Kingdom
# 196        13115       2294.78    Preferred  United Kingdom
# 56         12502       3723.87    Preferred  United Kingdom
# 294        13695       2504.13    Preferred  United Kingdom
# 1036       18008       2116.19    Preferred  United Kingdom
# 140        12823       1759.50    Preferred  United Kingdom
# 644        15640      12515.66          VIP  United Kingdom
# 146        12843       1702.26    Preferred  United Kingdom
# 882        17147       1714.59    Preferred  United Kingdom
# 571        15194       7616.53          VIP  United Kingdom
# 297        13709       6328.05          VIP  United Kingdom
# 131        12757       7857.10          VIP  United Kingdom
# 399        14235       3144.86    Preferred  United Kingdom
# 641        15622       3709.56    Preferred  United Kingdom
# 682        15845       3711.77    Preferred  United Kingdom
# 928        17419       4226.57    Preferred  United Kingdom
# 5          12356       2811.43    Preferred  United Kingdom
# 939        17463       1896.41    Preferred  United Kingdom
# 902        17272       2148.63    Preferred  United Kingdom
# 1017       17846       2033.10    Preferred  United Kingdom
# 190        13093       7832.47          VIP  United Kingdom
# 747        16258       5203.51    Preferred  United Kingdom
# 639        15606       2920.16    Preferred  United Kingdom
# 789        16607       3347.71    Preferred  United Kingdom
# 132        12758       2791.59    Preferred  United Kingdom

# %%
# Change CustomerID to a categorical to avoid calculations
data3['CustomerID'] = data3['CustomerID'].astype(object)
data3.dtypes
# Out:
# CustomerID       object
# amount_spent    float64
# Client Class     object
# Country          object
# dtype: object

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
# Filtering VIP label
where_are_my_vips=data3[data3['Client Class'] == 'VIP']
where_are_my_vips.sort_values(by='Country')
# Out:
#      CustomerID  amount_spent Client Class         Country
# 595       15311      60767.90          VIP            EIRE
# 218       13225       6463.84          VIP            EIRE
# 589       15290       7943.22          VIP            EIRE
# 216       13209       5891.61          VIP          France
# 169       12971      11189.91          VIP          France
# ...         ...           ...          ...             ...
# 361       14057       6217.96          VIP  United Kingdom
# 362       14060       6140.42          VIP  United Kingdom
# 363       14062      10464.85          VIP  United Kingdom
# 367       14096      65164.79          VIP  United Kingdom
# 1071      18229       7276.90          VIP  United Kingdom
#
# [217 rows x 4 columns]

# %%
print('The country that has the most VIP Customers is the', where_are_my_vips['Country'].max())
# Out:
# The country that has the most VIP Customers is the United Kingdom

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
# Filtering both VIP and Preferred label
where_are_my_vips_and_my_preferred=data3[(data3['Client Class'] == 'VIP') | (data3['Client Class'] == 'Preferred')]
where_are_my_vips_and_my_preferred.sort_values(by='Country')
# Out:
#      CustomerID  amount_spent Client Class          Country
# 198       13126       2099.64    Preferred  Channel Islands
# 197       13124       3866.33    Preferred  Channel Islands
# 204       13141       2388.75    Preferred          Denmark
# 203       13139       5064.94    Preferred          Denmark
# 202       13137       3650.41    Preferred          Denmark
# ...         ...           ...          ...              ...
# 410       14285       1910.01    Preferred   United Kingdom
# 411       14286       4628.75    Preferred   United Kingdom
# 412       14290       2314.65    Preferred   United Kingdom
# 399       14235       3144.86    Preferred   United Kingdom
# 1084      18287       1837.28    Preferred   United Kingdom
#
# [1085 rows x 4 columns]

# %%
print('The country that has the most VIP and Preferred Customers is the', where_are_my_vips_and_my_preferred['Country'].max())
# Out:
# The country that has the most VIP and Preferred Customers is the United Kingdom
